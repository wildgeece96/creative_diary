# %%
import numpy as np 
import scipy.signal as sg 

import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
M = 100
t = np.linspace(-1, 1, 100) 
morlet = sg.morlet(100)
sg.

# %%
plt.grid() 
plt.plot(t, morlet) 
plt.xlabel("time") 
plt.ylabel("amplitude")
# Out:
# Text(0, 0.5, 'amplitude')

# %%
plt.plot(sg.hilbert(10))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-7af714c430eb> in <module>
# ----> 1 plt.plot(sg.hilbert(10))
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/signal/signaltools.py in hilbert(x, N, axis)
#    1618         raise ValueError("x must be real.")
#    1619     if N is None:
# -> 1620         N = x.shape[axis]
#    1621     if N <= 0:
#    1622         raise ValueError("N must be positive.")
#
# IndexError: tuple index out of range

# %%
import numpy as np 
def ricker(N, s=1):
    """
    inputs : 
        N : length of wavelet.
        s : float. scale factor. 
    returns : 
        wavelet : ndarray. (N,). mother wavelet
    """
    sigma = 1
    t = np.linspace(-4*s, 4*s, N)  
    return 2/(np.sqrt(3*sigma)*np.pi**0.25)*(1 - (t/sigma)**2)*np.exp(- t**2 / (2*sigma**2))

# %%
import matplotlib.pyplot as plt 
plt.plot(ricker(100))
plt.title("ricker")
plt.savefig("ricker_plot.png")

# %%
def morlet(N, sigma=5, s=1.0):
    """
    inputs : 
        N : length of wavelet.
        sigma : float.  Default is 5.0
        s : float. scaling factor. 
    outputs : 
        wavelet : ndarray. (N,). mother wavelet
    """
    t = np.linspace(-s*2*np.pi, s*2*np.pi, N)
    kappa = np.exp(-0.5*(sigma**2))
    output = np.pi ** -0.25 * np.exp(-0.5*(t**2)) * (np.exp(1j*sigma*t) - kappa)      
    return output

# %%
morlet(10)
# Out:
# array([ 1.97370483e-06, -5.71336707e-05, -1.38870762e-02, -1.66609792e-01,
#        -8.45225990e-02,  5.30156985e-01, -8.45225990e-02, -1.66609792e-01,
#        -1.38870762e-02, -5.71336707e-05])

# %%
plt.plot(morlet(100))
plt.title("morlet")
plt.savefig("morlet_plot.png")
